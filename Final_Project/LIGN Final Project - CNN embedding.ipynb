# %%
import numpy as np
import pandas as pd
import bcolz as bz
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import time
from torch.autograd import Variable

# %%
import numpy as np
result = {"a": 1.1181753789488595, 'b': 0.5566080288678394, 'c': 0.4718269778030734, 'd': 0.48716683119447185, 'e': 1.0, 'f': 0.1395076201641266, 'g': 0.20941558441558442}

names = ['id','data']
formats = ['str','f8']
dtype = dict(names = names, formats=formats)
array = np.array(list(result.items()), dtype=dtype)

print(array)
# Out:
# [('',  1.11817538) ('',  0.55660803) ('',  0.47182698) ('',  0.48716683)
#  ('',  1.        ) ('',  0.13950762) ('',  0.20941558)]

# %%
def divide_string(sentence):
    s_l = sentence.split()
    r_l = []
    punc = [ '?', '!', '*']
    delete = ['%','^','&','_','>','<','\\','$', '+', '~','`', ',', '.', ';',
              '#', '@', '(', ')', '[' , ']', '/', '|', '{', '}', '"', '-', '=']
    for i in range(len(s_l)):
        tmp = 0
        flag = True;
        for j in range(len(s_l[i])):
            if s_l[i][j] in punc:
                if(flag):
                    r_l.append(s_l[i][tmp : j])
                tmp = j
                flag = True
            if s_l[i][j] in delete:
                if(flag):
                    r_l.append(s_l[i][tmp : j])
                tmp = j
                flag = False
            else:
                if(not flag):
                    tmp = tmp + 1;
                flag = True
        if(flag):
            r_l.append(s_l[i][ tmp : len(s_l[i]) ] )
    str_list = [x for x in r_l if x != '']
    return str_list

# %%
a = "THIS is a go(%*#od day!===thanks $%@%*(don't}}} know... ====================================="
b = divide_string(a)
print(len(b))
print(b)
# Out:
# 12
# ['THIS', 'is', 'a', 'go', '*', 'od', 'day', '!', 'thanks', '*', "don't", 'know']

# %%
vectors = bz.open(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\glove\27B.100.dat")[:]
words = pickle.load(open(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\glove\27B.100_words.pkl", 'rb'))
word2idx = pickle.load(open(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\glove\27B.100_idx.pkl", 'rb'))

glove = {w: vectors[word2idx[w]] for w in words}

# %%
# sents is a list of string
def remove_infrequent_words(sents):
    word_counts = {}
    divide_sentence = []
    #divide each sentence first
    for s in sents:
        tmp = divide_string(s)
        divide_sentence.append(tmp)
    
    # count the word
    for s in divide_sentence:
        for w in s:
            if w in word_counts:
                word_counts[w] += 1
            else:
                word_counts[w] = 1

    threshold = 20
    filtered_sents = []
    for s in divide_sentence:
        new_s = []
        for w in s:
            if word_counts[w] < threshold:
                new_s.append('<UNKNOWN>')
            else:
                new_s.append(w)
        filtered_sents.append(new_s)
    return filtered_sents

# %%
s = ["This is a good time!!", "You are pretty@$&^$@ happy", "test", "test*%& test"]
def prep_embedding_weight(sentence):
    #create the total size of weight matrix
    emb_dim = 100
    processed_sentence = remove_infrequent_words(sentence)
    
    vocab_size = 1;
    word_index = {"PADDING_STRING":0}
    
    #count the unique word that appares
    for k in range(len(processed_sentence)):
        target_vocab = processed_sentence[k]
        for i,word in enumerate(target_vocab):
            if word in word_index:
                a = 1;
            else:
                word_index[word] = vocab_size
                vocab_size += 1
                
    #error detector
    if(vocab_size != len(word_index)):
        print("Oops, Something wrong")
        return
    
    
    #create the pre-train weight matrix
    weights_matrix = np.zeros((vocab_size,100))
    unrecogized_word = 0;
    for key in word_index:
        try: 
            tmp_vec = np.random.normal(scale=0.6, size=(emb_dim, ))
        except KeyError:
            tmp_vec = np.random.normal(scale=0.6, size=(emb_dim, ))
        i = word_index[key]
        weights_matrix[i] = tmp_vec;
    #set the padding vector to be all zero
    weights_matrix[0] = np.zeros((emb_dim,))
    return weights_matrix, word_index

test, word =  prep_embedding_weight(s)
print(test.shape)
print(word["PADDING_STRING"])
# Out:
# (2, 100)
# 0

# %%
def prep_embedding_input(sentence, word_index):
    emb_input = np.zeros((len(sentence),100))
    processed_sentence = remove_infrequent_words(sentence)
    for k in range(len(processed_sentence)):
        target_vocab = processed_sentence[k]
        for i,word in enumerate(target_vocab):
            if i == 100:
                break
            try:
                value = word_index[word]
            except:
                value = word_index["<UNKNOWN>"]
            emb_input[k][i] = value
    return emb_input

# %%
def create_emb_layer(weights_matrix, non_trainable=False):
    num_embeddings, embedding_dim = weights_matrix.shape
    emb_layer = nn.Embedding(num_embeddings, embedding_dim)
    emb_layer.load_state_dict({'weight': weights_matrix})
    if non_trainable:
        emb_layer.weight.requires_grad = False

    return emb_layer, num_embeddings, embedding_dim


class tcCNN(nn.Module):
    def __init__(self, batch_size, vocab_size, pretrained_weight):
        super(tcCNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, 100)
        self.embedding.weight.data.copy_(torch.from_numpy(pretrained_weight))
        
        
        self.batch_size = batch_size
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=(5,100), stride=1),
            nn.ReLU(),
            nn.Dropout(0.2)
        )
        self.bn_layer = nn.BatchNorm2d(64)
        self.fc = nn.Sequential(nn.Linear(64*1*96, 50),
                                nn.Dropout())
        self.out_layer = nn.Linear(50,6)
        

        
    def forward(self, sentences):
        #didn't use batch, may need to add batch size in the middle
        out = self.embedding(sentences)
        out = self.layer1(out)
        out = self.bn_layer(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        y_pred = self.out_layer(out)
        
        return torch.sigmoid(y_pred)

# %%
data = pd.read_csv(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\data\train.csv", encoding = "ISO-8859-1")
#data.head()

# %%
x_train = data['comment_text'] 
y_train = data.iloc[:,2:8]
print(x_train.shape)
print(y_train.shape)
# Out:
# (159571,)
# (159571, 6)

# %%
data = pd.read_csv(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\data\test.csv", encoding = "ISO-8859-1")
x_test = data['comment_text']
print(x_test.shape)
data = pd.read_csv(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\data\test_labels.csv", encoding = "ISO-8859-1")
y_test = data.iloc[:,1:7]
print(y_test.shape)
# Out:
# (153164,)
# (153164, 6)

# %%
#the embedding
start = time.time()
weights_matrix, word_index = prep_embedding_weight(x_train)
train_set = prep_embedding_input(x_train, word_index)

print(train_set.shape)
print(weights_matrix.shape)
print(len(word_index))
end = time.time()
print(end - start)
# Out:
# (159571, 100)
# (20452, 100)
# 20452
# 61.028754472732544

# %%
train_set_s = train_set[:30000,:]
validation_x = train_set[30000:40000,:].reshape((10000,1,100))
print(train_set_s.shape)
print(validation_x.shape)
# Out:
# (30000, 100)
# (10000, 1, 100)

# %%
data = pd.read_csv(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\data\test.csv", encoding = "ISO-8859-1")
data2 = pd.read_csv(r"C:\Users\mul02\Desktop\Course\LIGN 167\Final Project\data\test_labels.csv", encoding = "ISO-8859-1")
df = pd.concat([data.reset_index(drop=True), data2.reset_index(drop=True)], axis=1)
df = df.drop(['id', 'id'],axis=1)
df = df[df.toxic != -1]
print(data.shape)
print(data2.shape)
print(df.shape)
x_test = df.reset_index()['comment_text']
y_test = df.reset_index().iloc[:, 2:8]
print(x_test.shape)
print(y_test.shape)
# Out:
# (153164, 2)
# (153164, 7)
# (63978, 7)
# (63978,)
# (63978, 6)

# %%
batch_size = 512
epoch = 200
lr = 0.005
output_dim = 6
input_dim = 100
#train_size = len(x_train)
train_size = 30000
train_output = y_train.values
validation_y = train_output[30000:40000]
vocab_size = (len(word_index))
print(validation_y.shape)


model = tcCNN(batch_size = batch_size,vocab_size=vocab_size, pretrained_weight=weights_matrix)
model = model.cuda()
loss_fn = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# (10000, 6)

# %%
#then do the testing
#first test on 10000 set


def evaluation(test_set, test_output):
    correct = 0
    total = len(test_output)
    with torch.no_grad():
        x_t = torch.cuda.LongTensor(test_set)
        y_t = torch.cuda.FloatTensor(test_output)
        y_pred = model(x_t)
        y_pred = y_pred.reshape((total, 6))
        y_pred_c = y_pred > 0.6
        y_pred_c = y_pred_c.type(torch.cuda.FloatTensor)
        for i in range(total):
            if torch.equal(y_pred_c[i], y_t[i]):
                correct = correct + 1
        print(correct)

# %%
start = time.time()

#Training

for i in range(epoch):  # again, normally you would NOT do 300 epochs, it is toy data
    j = 0
    total_loss = 0
    while(j < train_size ):
        k = j + 512;
        if k > train_size:
            break
        
        #prepare input and output
        x_t = train_set_s[j:k,:]
        x_t = x_t.reshape(512,1,100)
        x_t = torch.cuda.LongTensor(x_t)
        y_t = train_output[j:k,:]
        #y_t = y_t.sum(axis=1)
        y_t = torch.cuda.FloatTensor(y_t)
        
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()



        # Step 2. Run our forward pass.
        y_pred = model(x_t)
        y_pred = y_pred.reshape((512,6))
        
        
        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        loss = loss_fn(y_pred, y_t)
        total_loss += loss
        loss.backward()
        optimizer.step()
        j = k
    evaluation(validation_x, validation_y)
    print(total_loss)
        
        
end = time.time()
print(end - start)
# Out:
# 8948
# tensor(10.6096, device='cuda:0', grad_fn=<ThAddBackward>)
# 8916
# tensor(4.9228, device='cuda:0', grad_fn=<ThAddBackward>)
# 8918
# tensor(3.5311, device='cuda:0', grad_fn=<ThAddBackward>)
# 8966
# tensor(2.9950, device='cuda:0', grad_fn=<ThAddBackward>)
# 8973
# tensor(3.2002, device='cuda:0', grad_fn=<ThAddBackward>)
# 8793
# tensor(2.9431, device='cuda:0', grad_fn=<ThAddBackward>)
# 8505
# tensor(2.5122, device='cuda:0', grad_fn=<ThAddBackward>)
# 8840
# tensor(2.3885, device='cuda:0', grad_fn=<ThAddBackward>)
# 9013
# tensor(2.0562, device='cuda:0', grad_fn=<ThAddBackward>)
# 8846
# tensor(1.8134, device='cuda:0', grad_fn=<ThAddBackward>)
# 8766
# tensor(1.5040, device='cuda:0', grad_fn=<ThAddBackward>)
# 8966
# tensor(1.3484, device='cuda:0', grad_fn=<ThAddBackward>)
# 8945
# tensor(1.2665, device='cuda:0', grad_fn=<ThAddBackward>)
# 8961
# tensor(1.1444, device='cuda:0', grad_fn=<ThAddBackward>)
# 8992
# tensor(1.0924, device='cuda:0', grad_fn=<ThAddBackward>)
# 8986
# tensor(1.1742, device='cuda:0', grad_fn=<ThAddBackward>)
# 9003
# tensor(1.1701, device='cuda:0', grad_fn=<ThAddBackward>)
# 8900
# tensor(1.1224, device='cuda:0', grad_fn=<ThAddBackward>)
# 8723
# tensor(1.4964, device='cuda:0', grad_fn=<ThAddBackward>)
# 8669
# tensor(1.7499, device='cuda:0', grad_fn=<ThAddBackward>)
# 8965
# tensor(1.4486, device='cuda:0', grad_fn=<ThAddBackward>)
# 8951
# tensor(1.1116, device='cuda:0', grad_fn=<ThAddBackward>)
# 8913
# tensor(1.0042, device='cuda:0', grad_fn=<ThAddBackward>)
# 8843
# tensor(0.7771, device='cuda:0', grad_fn=<ThAddBackward>)
# 8751
# tensor(0.6384, device='cuda:0', grad_fn=<ThAddBackward>)
# 8614
# tensor(0.6160, device='cuda:0', grad_fn=<ThAddBackward>)
# 8679
# tensor(0.5868, device='cuda:0', grad_fn=<ThAddBackward>)
# 8773
# tensor(0.6079, device='cuda:0', grad_fn=<ThAddBackward>)
# 8687
# tensor(0.5103, device='cuda:0', grad_fn=<ThAddBackward>)
# 8754
# tensor(0.5209, device='cuda:0', grad_fn=<ThAddBackward>)
# 8618
# tensor(0.4953, device='cuda:0', grad_fn=<ThAddBackward>)
# 8784
# tensor(0.4616, device='cuda:0', grad_fn=<ThAddBackward>)
# 8903
# tensor(0.3875, device='cuda:0', grad_fn=<ThAddBackward>)
# 8922
# tensor(0.3506, device='cuda:0', grad_fn=<ThAddBackward>)
# 8961
# tensor(0.3549, device='cuda:0', grad_fn=<ThAddBackward>)
# 8982
# tensor(0.4143, device='cuda:0', grad_fn=<ThAddBackward>)
# 8937
# tensor(0.3897, device='cuda:0', grad_fn=<ThAddBackward>)
# 8954
# tensor(0.3300, device='cuda:0', grad_fn=<ThAddBackward>)
# 8941
# tensor(0.3064, device='cuda:0', grad_fn=<ThAddBackward>)
# 8912
# tensor(0.3202, device='cuda:0', grad_fn=<ThAddBackward>)
# 8841
# tensor(0.2915, device='cuda:0', grad_fn=<ThAddBackward>)
# 8785
# tensor(0.3221, device='cuda:0', grad_fn=<ThAddBackward>)
# 8778
# tensor(0.3292, device='cuda:0', grad_fn=<ThAddBackward>)
# 8785
# tensor(0.3527, device='cuda:0', grad_fn=<ThAddBackward>)
# 8721
# tensor(0.2986, device='cuda:0', grad_fn=<ThAddBackward>)
# 8769
# tensor(0.2907, device='cuda:0', grad_fn=<ThAddBackward>)
# 8813
# tensor(0.2420, device='cuda:0', grad_fn=<ThAddBackward>)
# 8761
# tensor(0.2687, device='cuda:0', grad_fn=<ThAddBackward>)
# 8762
# tensor(0.2581, device='cuda:0', grad_fn=<ThAddBackward>)
# 8714
# tensor(0.3111, device='cuda:0', grad_fn=<ThAddBackward>)
# 8840
# tensor(0.3052, device='cuda:0', grad_fn=<ThAddBackward>)
# 8800
# tensor(0.2441, device='cuda:0', grad_fn=<ThAddBackward>)
# 8816
# tensor(0.2657, device='cuda:0', grad_fn=<ThAddBackward>)
# 8811
# tensor(0.2662, device='cuda:0', grad_fn=<ThAddBackward>)
# 8784
# tensor(0.3152, device='cuda:0', grad_fn=<ThAddBackward>)
# 8814
# tensor(0.2296, device='cuda:0', grad_fn=<ThAddBackward>)
# 8892
# tensor(0.2262, device='cuda:0', grad_fn=<ThAddBackward>)
# 8838
# tensor(0.2405, device='cuda:0', grad_fn=<ThAddBackward>)
# 8887
# tensor(0.2598, device='cuda:0', grad_fn=<ThAddBackward>)
# 8923
# tensor(0.2640, device='cuda:0', grad_fn=<ThAddBackward>)
# 8924
# tensor(0.2902, device='cuda:0', grad_fn=<ThAddBackward>)
# 8916
# tensor(0.3351, device='cuda:0', grad_fn=<ThAddBackward>)
# 8968
# tensor(0.3014, device='cuda:0', grad_fn=<ThAddBackward>)
# 8979
# tensor(0.3116, device='cuda:0', grad_fn=<ThAddBackward>)
# 8992
# tensor(0.3366, device='cuda:0', grad_fn=<ThAddBackward>)
# 8924
# tensor(0.3134, device='cuda:0', grad_fn=<ThAddBackward>)
# 8948
# tensor(0.3315, device='cuda:0', grad_fn=<ThAddBackward>)
# 8942
# tensor(0.2703, device='cuda:0', grad_fn=<ThAddBackward>)
# 8946
# tensor(0.2279, device='cuda:0', grad_fn=<ThAddBackward>)
# 8935
# tensor(0.2585, device='cuda:0', grad_fn=<ThAddBackward>)
# 8940
# tensor(0.2669, device='cuda:0', grad_fn=<ThAddBackward>)
# 8977
# tensor(0.2806, device='cuda:0', grad_fn=<ThAddBackward>)
# 8989
# tensor(0.2834, device='cuda:0', grad_fn=<ThAddBackward>)
# 8976
# tensor(0.2916, device='cuda:0', grad_fn=<ThAddBackward>)
# 8970
# tensor(0.2775, device='cuda:0', grad_fn=<ThAddBackward>)
# 8963
# tensor(0.3246, device='cuda:0', grad_fn=<ThAddBackward>)
# 8912
# tensor(0.2762, device='cuda:0', grad_fn=<ThAddBackward>)
# 8987
# tensor(0.2905, device='cuda:0', grad_fn=<ThAddBackward>)
# 8963
# tensor(0.2710, device='cuda:0', grad_fn=<ThAddBackward>)
# 8983
# tensor(0.2831, device='cuda:0', grad_fn=<ThAddBackward>)
# 8984
# tensor(0.3735, device='cuda:0', grad_fn=<ThAddBackward>)
# 8975
# tensor(0.3837, device='cuda:0', grad_fn=<ThAddBackward>)
# 8978
# tensor(0.4793, device='cuda:0', grad_fn=<ThAddBackward>)
# 8961
# tensor(0.4347, device='cuda:0', grad_fn=<ThAddBackward>)
# 8932
# tensor(0.4190, device='cuda:0', grad_fn=<ThAddBackward>)
# 8867
# tensor(0.4472, device='cuda:0', grad_fn=<ThAddBackward>)
# 8853
# tensor(0.5257, device='cuda:0', grad_fn=<ThAddBackward>)
# 8785
# tensor(0.6082, device='cuda:0', grad_fn=<ThAddBackward>)
# 8725
# tensor(0.5983, device='cuda:0', grad_fn=<ThAddBackward>)
# 8763
# tensor(0.6719, device='cuda:0', grad_fn=<ThAddBackward>)
# 8814
# tensor(0.6286, device='cuda:0', grad_fn=<ThAddBackward>)
# 8836
# tensor(0.7666, device='cuda:0', grad_fn=<ThAddBackward>)
# 8779
# tensor(0.5430, device='cuda:0', grad_fn=<ThAddBackward>)
# 8802
# tensor(0.6302, device='cuda:0', grad_fn=<ThAddBackward>)
# 8540
# tensor(0.7399, device='cuda:0', grad_fn=<ThAddBackward>)
# 8345
# tensor(0.5928, device='cuda:0', grad_fn=<ThAddBackward>)
# 8438
# tensor(0.6850, device='cuda:0', grad_fn=<ThAddBackward>)
# 8423
# tensor(0.7195, device='cuda:0', grad_fn=<ThAddBackward>)
# 8240
# tensor(0.7295, device='cuda:0', grad_fn=<ThAddBackward>)
# 8651
# tensor(0.6292, device='cuda:0', grad_fn=<ThAddBackward>)
# 8798
# tensor(0.5979, device='cuda:0', grad_fn=<ThAddBackward>)
# 8801
# tensor(0.7964, device='cuda:0', grad_fn=<ThAddBackward>)
# 8812
# tensor(0.7407, device='cuda:0', grad_fn=<ThAddBackward>)
# 8880
# tensor(0.6002, device='cuda:0', grad_fn=<ThAddBackward>)
# 8929
# tensor(0.5057, device='cuda:0', grad_fn=<ThAddBackward>)
# 8918
# tensor(0.3722, device='cuda:0', grad_fn=<ThAddBackward>)
# 8866
# tensor(0.2342, device='cuda:0', grad_fn=<ThAddBackward>)
# 8842
# tensor(0.2320, device='cuda:0', grad_fn=<ThAddBackward>)
# 8913
# tensor(0.2376, device='cuda:0', grad_fn=<ThAddBackward>)
# 8853
# tensor(0.1798, device='cuda:0', grad_fn=<ThAddBackward>)
# 8908
# tensor(0.1671, device='cuda:0', grad_fn=<ThAddBackward>)
# 8907
# tensor(0.1268, device='cuda:0', grad_fn=<ThAddBackward>)
# 8894
# tensor(0.1059, device='cuda:0', grad_fn=<ThAddBackward>)
# 8899
# tensor(0.1572, device='cuda:0', grad_fn=<ThAddBackward>)
# 8835
# tensor(0.1365, device='cuda:0', grad_fn=<ThAddBackward>)
# 8905
# tensor(0.1576, device='cuda:0', grad_fn=<ThAddBackward>)
# 8923
# tensor(0.1159, device='cuda:0', grad_fn=<ThAddBackward>)
# 8925
# tensor(0.1278, device='cuda:0', grad_fn=<ThAddBackward>)
# 8880
# tensor(0.0936, device='cuda:0', grad_fn=<ThAddBackward>)
# 8883
# tensor(0.0982, device='cuda:0', grad_fn=<ThAddBackward>)
# 8855
# tensor(0.1089, device='cuda:0', grad_fn=<ThAddBackward>)
# 8876
# tensor(0.1374, device='cuda:0', grad_fn=<ThAddBackward>)
# 8884
# tensor(0.1277, device='cuda:0', grad_fn=<ThAddBackward>)
# 8908
# tensor(0.1013, device='cuda:0', grad_fn=<ThAddBackward>)
# 8905
# tensor(0.1130, device='cuda:0', grad_fn=<ThAddBackward>)
# 8875
# tensor(0.1374, device='cuda:0', grad_fn=<ThAddBackward>)
# 8891
# tensor(0.1323, device='cuda:0', grad_fn=<ThAddBackward>)
# 8889
# tensor(0.1304, device='cuda:0', grad_fn=<ThAddBackward>)
# 8902
# tensor(0.1192, device='cuda:0', grad_fn=<ThAddBackward>)
# 8900
# tensor(0.1280, device='cuda:0', grad_fn=<ThAddBackward>)
# 8855
# tensor(0.0911, device='cuda:0', grad_fn=<ThAddBackward>)
# 8881
# tensor(0.1090, device='cuda:0', grad_fn=<ThAddBackward>)
# 8804
# tensor(0.1286, device='cuda:0', grad_fn=<ThAddBackward>)
# 8927
# tensor(0.1099, device='cuda:0', grad_fn=<ThAddBackward>)
# 8933
# tensor(0.1046, device='cuda:0', grad_fn=<ThAddBackward>)
# 8856
# tensor(0.1379, device='cuda:0', grad_fn=<ThAddBackward>)
# 8924
# tensor(0.1131, device='cuda:0', grad_fn=<ThAddBackward>)
# 8915
# tensor(0.1401, device='cuda:0', grad_fn=<ThAddBackward>)
# 8928
# tensor(0.1229, device='cuda:0', grad_fn=<ThAddBackward>)
# 8868
# tensor(0.1541, device='cuda:0', grad_fn=<ThAddBackward>)
# 8897
# tensor(0.1029, device='cuda:0', grad_fn=<ThAddBackward>)
# 8924
# tensor(0.1517, device='cuda:0', grad_fn=<ThAddBackward>)
# 8886
# tensor(0.1677, device='cuda:0', grad_fn=<ThAddBackward>)
# 8856
# tensor(0.2165, device='cuda:0', grad_fn=<ThAddBackward>)
# 8826
# tensor(0.1614, device='cuda:0', grad_fn=<ThAddBackward>)
# 8863
# tensor(0.1148, device='cuda:0', grad_fn=<ThAddBackward>)
# 8896
# tensor(0.1332, device='cuda:0', grad_fn=<ThAddBackward>)
# 8937
# tensor(0.1685, device='cuda:0', grad_fn=<ThAddBackward>)
# 8904
# tensor(0.1699, device='cuda:0', grad_fn=<ThAddBackward>)
# 8809
# tensor(0.1884, device='cuda:0', grad_fn=<ThAddBackward>)
# 8918
# tensor(0.2022, device='cuda:0', grad_fn=<ThAddBackward>)
# 8728
# tensor(0.2258, device='cuda:0', grad_fn=<ThAddBackward>)
# 8880
# tensor(0.2016, device='cuda:0', grad_fn=<ThAddBackward>)
# 8729
# tensor(0.1955, device='cuda:0', grad_fn=<ThAddBackward>)
# 8765
# tensor(0.2005, device='cuda:0', grad_fn=<ThAddBackward>)
# 8829
# tensor(0.2554, device='cuda:0', grad_fn=<ThAddBackward>)
# 8920
# tensor(0.2512, device='cuda:0', grad_fn=<ThAddBackward>)
# 8921
# tensor(0.2650, device='cuda:0', grad_fn=<ThAddBackward>)
# 8855
# tensor(0.2166, device='cuda:0', grad_fn=<ThAddBackward>)
# 8859
# tensor(0.2308, device='cuda:0', grad_fn=<ThAddBackward>)
# 8849
# tensor(0.2060, device='cuda:0', grad_fn=<ThAddBackward>)
# 8902
# tensor(0.2121, device='cuda:0', grad_fn=<ThAddBackward>)
# 8848
# tensor(0.2212, device='cuda:0', grad_fn=<ThAddBackward>)
# 8870
# tensor(0.1896, device='cuda:0', grad_fn=<ThAddBackward>)
# 8924
# tensor(0.1635, device='cuda:0', grad_fn=<ThAddBackward>)
# 8897
# tensor(0.1959, device='cuda:0', grad_fn=<ThAddBackward>)
# 8909
# tensor(0.1927, device='cuda:0', grad_fn=<ThAddBackward>)
# 8926
# tensor(0.1551, device='cuda:0', grad_fn=<ThAddBackward>)
# 8937
# tensor(0.2010, device='cuda:0', grad_fn=<ThAddBackward>)
# 8855
# tensor(0.1553, device='cuda:0', grad_fn=<ThAddBackward>)
# 8837
# tensor(0.2097, device='cuda:0', grad_fn=<ThAddBackward>)
# 8855
# tensor(0.1017, device='cuda:0', grad_fn=<ThAddBackward>)
# 8848
# tensor(0.1582, device='cuda:0', grad_fn=<ThAddBackward>)
# 8911
# tensor(0.1504, device='cuda:0', grad_fn=<ThAddBackward>)
# 8802
# tensor(0.1533, device='cuda:0', grad_fn=<ThAddBackward>)
# 8770
# tensor(0.2222, device='cuda:0', grad_fn=<ThAddBackward>)
# 8887
# tensor(0.1623, device='cuda:0', grad_fn=<ThAddBackward>)
# 8871
# tensor(0.1813, device='cuda:0', grad_fn=<ThAddBackward>)
# 8850
# tensor(0.1914, device='cuda:0', grad_fn=<ThAddBackward>)
# 8868
# tensor(0.1934, device='cuda:0', grad_fn=<ThAddBackward>)
# 8897
# tensor(0.1441, device='cuda:0', grad_fn=<ThAddBackward>)
# 8952
# tensor(0.1724, device='cuda:0', grad_fn=<ThAddBackward>)
# 8910
# tensor(0.1609, device='cuda:0', grad_fn=<ThAddBackward>)
# 8886
# tensor(0.1888, device='cuda:0', grad_fn=<ThAddBackward>)
# 8778
# tensor(0.2028, device='cuda:0', grad_fn=<ThAddBackward>)
# 8814
# tensor(0.1760, device='cuda:0', grad_fn=<ThAddBackward>)
# 8879
# tensor(0.2836, device='cuda:0', grad_fn=<ThAddBackward>)
# 8864
# tensor(0.2315, device='cuda:0', grad_fn=<ThAddBackward>)
# 8828
# tensor(0.1643, device='cuda:0', grad_fn=<ThAddBackward>)
# 8859
# tensor(0.1318, device='cuda:0', grad_fn=<ThAddBackward>)
# 8914
# tensor(0.1674, device='cuda:0', grad_fn=<ThAddBackward>)
# 8906
# tensor(0.1643, device='cuda:0', grad_fn=<ThAddBackward>)
# 8805
# tensor(0.1417, device='cuda:0', grad_fn=<ThAddBackward>)
# 8894
# tensor(0.1694, device='cuda:0', grad_fn=<ThAddBackward>)
# 8926
# tensor(0.1984, device='cuda:0', grad_fn=<ThAddBackward>)
# 8890
# tensor(0.2226, device='cuda:0', grad_fn=<ThAddBackward>)
# 8854
# tensor(0.2424, device='cuda:0', grad_fn=<ThAddBackward>)
# 8740
# tensor(0.2503, device='cuda:0', grad_fn=<ThAddBackward>)
# 8754
# tensor(0.2152, device='cuda:0', grad_fn=<ThAddBackward>)
# 8891
# tensor(0.2099, device='cuda:0', grad_fn=<ThAddBackward>)
# 606.5328869819641

# %%
#test set
total = 10000
test_set_d = x_test[10000:20000]
test_output = y_test.values[10000:20000, :]
test_set = prep_embedding_input(test_set_d, word_index)
#test_set = base_glove_total(test_set_d)
test_set = test_set.reshape((total,1,100))
print(len(glove))
# Out:
# 1193514

# %%
evaluation(test_set, test_output)
# Out:
# 8847
